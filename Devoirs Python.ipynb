# %%
import numpy as np 
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt

# %%
corse=pd.read_csv("hotellerie_moyennesejour.csv",sep=";")

# %%
corse
# Out:
#     Annee       Mois  Moyenne
# 0    2012  Septembre     2.14
# 1    2015   Novembre     1.53
# 2    2012       Mars     1.63
# 3    2013       Juin     2.10
# 4    2017       Aout     2.74
# 5    2015  Septembre     2.20
# 6    2016        Mai     1.97
# 7    2014        Mai     1.89
# 8    2012      Avril     1.83
# 9    2014       Aout     2.63
# 10   2014  Septembre     2.17
# 11   2016    Fevrier     1.57
# 12   2017        Mai     2.04
# 13   2017    Fevrier     1.63
# 14   2012    Juillet     2.76
# 15   2013      Avril     1.88
# 16   2015    Fevrier     1.59
# 17   2016    Octobre     2.01
# 18   2012    Octobre     1.85
# 19   2013    Fevrier     1.59
# 20   2014       Mars     1.54
# 21   2015    Janvier     1.69
# 22   2015    Juillet     2.62
# 23   2016   Decembre     1.57
# 24   2012   Decembre     1.58
# 25   2012   Novembre     1.57
# 26   2013        Mai     2.01
# 27   2015      Avril     1.82
# 28   2017    Janvier     1.63
# 29   2015       Juin     2.18
# ...

# %%
nb_lignes, nb_col = corse.shape
print(nb_lignes)
print(nb_col)
# Out:
# 70
# 3

# %%
#Top 10 des mois ou la durée moyenne est la plus longue 
(corse.Moyenne.sort_values()[-10:])
# Out:
# 54    2.61
# 22    2.62
# 9     2.63
# 37    2.64
# 61    2.64
# 46    2.69
# 4     2.74
# 14    2.76
# 33    2.80
# 56    2.82
# Name: Moyenne, dtype: float64

# %%
#Année ou le mois daout a eu la moyenne la plus longue
corse[(corse.Mois=="Aout")].sort_values(by='Moyenne')[-1:]
# Out:
#     Annee  Mois  Moyenne
# 56   2012  Aout     2.82

# %%
#Année ou la durée de sejour moyenne etait la plus courte
corse.groupby(corse.Annee).Moyenne.sum().sort_values()[:10]
# Out:
# Annee
# 2017    20.32
# 2014    22.75
# 2013    23.16
# 2015    23.40
# 2016    23.57
# 2012    23.63
# Name: Moyenne, dtype: float64

# %%
corse[(corse.Mois=="Aout")].Moyenne.plot()

# %%
# Out:
#   File "<ipython-input-23-fd0e1e08b5e9>", line 1
#     year=corse.Annee and (corse.Mois="Aout")
#                                     ^
# SyntaxError: invalid syntax
